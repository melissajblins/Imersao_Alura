# %% [markdown]
# <a href="https://colab.research.google.com/github/melissajblins/Imersao_Alura/blob/main/ImersaoAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imersão dados Alura
# Link das anotações e resumo das aulas: https://docs.google.com/document/d/1OhY7Wn_38Yn0f88btO4KsV2kFRhQszlnyLmjDFyOA7c/edit#heading=h.igi5tpisdn07

# %% [markdown]
# ================================================================================
#
# ### AULA 01 - ANÁLISE DE DADOS, PYTHON, PANDAS E NOVOS FÁRMACOS

# %%
import pandas as pd #importando biblioteca pandas

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true' #puxando a base de dados

dados = pd.read_csv(url_dados, compression = 'zip') #lendo e armazenando a base de dados
dados #imprimindo a base de dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head() #imprimindo a primeira linha da minha base de dados
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape #conferindo quantas linhas e colunas tem a minha base de dados
# Out:
# (23814, 877)

# %%
dados['tratamento'] #observando a coluna "tratamento"
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #observando quais valores há na coluna "tratamento"
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique() #observando quais valores há na coluna "tempo"
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique() #observando quais valores há na coluna "dose"
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique() #observando quais valores há na coluna "droga"
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique() #observando quais valores há na coluna "g-0"
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts() #conferindo a relação entre os valores da coluna "tratamento"
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 01: Por que há um desbalanceamento tão grande entre os tratamentos com droga e com controle?

# %% [markdown]
# O tratamento com controle é utilizado para mensurar a diferenças entre as pessoas que não receberam o composto, isto é, se encontram em um estado natural, e entre aqueles que receberam o composto. É necessário para identificar se houve realmente uma alteração no que diz respeito à expressão gênica. Nesse caso, a nossa base de dados utilizou a mesma substância como tratamento de controle.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 02: Como plotar as últimas 5 linhas da tabela?

# %%
dados.tail() #plotando as últimas 5 linhas da minha base da dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 03: Quantos tipos de drogas foram investigadas?

# %%
dados['droga'].value_counts() #descobrindo a quantidade de drogas investigadas vendo o tamanho dos valores
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# a90e40334       1
# fb8a93a83       1
# 1d39c75d6       1
# 161572520       1
# bef38f2fd       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
dados['dose'].value_counts() #contando os valores da coluna "dose"
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 04: Como contar a proporção das classes de tratamento?

# %%
dados['tratamento'].value_counts(normalize = True) #contando a proporção das classes da coluna "tratamento"
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
dados['dose'].value_counts(normalize = True) #contando a proporção das classes da coluna "dose"
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie() #plotando gráfico de pizza da coluna "tratamento"

# %%
dados['tempo'].value_counts().plot.pie() #plotando gráfico de pizza da coluna "tempo"

# %%
dados['tempo'].value_counts().plot.bar() #plotando gráfico de barras da coluna "tempo"

# %%
dados['g-0'] > 0 #conferindo quais valores da coluna g-0 são maiores do que 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0'] > 0] #armazenando em uma variável os valores da coluna g-0 são maiores do que 0

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 05: Procurar na documentação o método query(pandas).

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 06: Renomear as colunas tirando o hífen.

# %%
nome_colunas = dados.columns #armazenando em uma variável as colunas

# %%
novo_nome_colunas = [] #criando um vetor para as novas colunas
for coluna in nome_colunas: #criando uma estrutura de laço
  coluna = coluna.replace('-', '_') #substituindo '-' por '_'
  novo_nome_colunas.append(coluna) #adicionando ao vetor as novas colunas
dados.columns #mostrando as colunas
dados.head() #mostrando as 5 primeiras linhas da tabela
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 07: Adicionar label nos gráficos (Matplotlib.pyplot).

# %%
import matplotlib.pyplot as plt #importando matplotlib.pyplot

# %%
valores_tempo = dados['tempo'].value_counts(ascending = True) #armazenando em uma variável os valores ascendentes da coluna tempo
valores_tempo.sort_index() #organizando pelo index
# Out:
# 24    7772
# 48    8250
# 72    7792
# Name: tempo, dtype: int64

# %% [markdown]
# ================================================================================
#
# ##AULA 2 -  ESTATÍSTICAS, VISUALIZAÇÃO DE DADOS E DISTRIBUIÇÕES

# %% [markdown]
# **Alterar nome de coluna**
#
# mapa = {'droga': 'composto'}
#
# dados.rename(columns = mapa, inplace=True)
#
# *Cuidado: Não fazer alterações no meio do código*

# %%
dados.head() #mostrando as 5 primeiras linhas da tabela
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Montar gráfico com o seaborn:
#
# Para o caso da coluna “droga”, não é viável fazer um gráfico de todos os elementos, uma vez que ficaria impossível de ser lido e interpretado. **Solução: Exibir os 5 elementos mais citados**.
#
# Código para todos os elementos:
#
# ```
# import seaborn as sns
#
# sns.countplot(x = 'droga', data = dados)
# ```

# %%
maiores_compostos = dados['droga'].value_counts().index[0:5] #armazenando em uma variável os 5 compostos mais utilizados
maiores_compostos #imprimindo os 5 compostos mais utilizados
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('droga in @maiores_compostos') #selecionando as drogas que correspondem aos 5 compostos mais utilizados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns #importando seaborn
import matplotlib.pyplot as plt #importando matplotlib.pyplot
sns.set()
plt.figure(figsize=(8, 6)) #aumentando o tamanho da figura
ax = sns.countplot(x = 'droga', data = dados.query('droga in @maiores_compostos')) #selecionando os 5 maiores compostos para o eixo x
ax.set_title('5 compostos mais utilizados') #definindo um título para o gráfico
plt.show() #mostrando o gráfico

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 01: Ordenar o gráfico acima.

# %%
sns.set()
plt.figure(figsize = (8, 6)) #aumentando o tamanho da imagem
ax = sns.countplot(x = 'droga', data = dados.query('droga in @maiores_compostos'), order = maiores_compostos) #montando o gráfico ordenado
plt.show() #mostrando o gráfico

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 02: Melhorar a parte estética do gráfico acima.

# %% [markdown]
# *Adicionar título*
#
# *Adicionar eixos*

# %%
sns.set()

plt.rc('axes', titlesize = 20) #Tamanho do título
plt.rc('axes', labelsize = 18) #Tamanho das legendas
plt.rc('xtick', labelsize = 14) #Tamanho dos eixo x
plt.rc('ytick', labelsize = 14) #Tamanho do eixo y

plt.figure(figsize = (8, 6)) #Aumentando a figura

ax = sns.countplot (x = 'droga', data = dados.query('droga in @maiores_compostos'), order = maiores_compostos) #Montando o gráfico ordenado

ax.set_title('5 compostos mais utilizados') #Definindo título
ax.set_xlabel('Droga') #Definindo legenda do eixo x
ax.set_ylabel('Proporção') #Definindo legenda do eixo y

plt.show() #Mostrando o gráfico

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
len(dados['g-0'].unique()) #Conferindo o tamanho dos dados únicos da coluna g-0
# Out:
# 14367

# %%
dados['g-0'].min() #Conferindo o valor mínimo da coluna g-0
# Out:
# -5.513

# %%
dados['g-0'].max() #Conferindo o valor máximo da coluna g-0
# Out:
# 10.0

# %%
dados['g-0'].hist(bins=100) #Plotando um gráfico de histograma

# %%
dados.describe() #Estabelendo os valores estatísticos da base da dados
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']] #Mostrando as colunas g-0 e g-1
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe() #Mostrando os valores estatísticos do g-0 até o g-771
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['mean'].hist(bins = 100) #Montando um histograma da média do g-0 aé o g-771

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['min'].hist(bins = 100) #Montando um histograma do mínimo do g-0 até o g-771

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['max'].hist(bins = 100) #Montando um histograma do máximo do g-0 até o g-771

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 03: Plotar os gráficos com seaborn.

# %%
sns.histplot(data = dados['g-0'],bins = 100) #Plotando g-0 com seaborn

# %%
sns.histplot(data = dados.loc[:,'g-0':'g-771'].describe().T['mean'],bins=100) #Plotando média com Seaborn

# %%
sns.histplot(data = dados.loc[:,'g-0':'g-771'].describe().T['min'],bins = 100) #Plotando mínimo com Seaborn

# %%
sns.histplot(data = dados.loc[:,'g-0':'g-771'].describe().T['max'],bins = 100) #Plotando máximo Seaborn

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 04: Estudar as medidas estatísticas do describe.

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
dados.loc[:, 'c-0':'c-99'].describe().T['mean'].hist(bins = 100) #Plotando gráfico de c-0 até o c-99

# %%
sns.boxplot(x = "g-0", data = dados) #Plotando gráfico boxplot do gene g-0

# %%
sns.boxplot(x = "g-0", y = 'tratamento', data = dados) #Plotando gráfico boxplot do gene-0 e da coluna tratamento

# %%
sns.boxplot(x = "tratamento", y = 'g-0', data = dados) #Invertendo os eixos do gráfico acima

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 05: Manipulação de gráficos.

# %% [markdown]
# A visualização dos gráficos deve ser adequada para que a extração de dados seja feita sem impedimentos no que tange à parte estética dos mesmos.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 06: Plotar outros gráficos boxplot e analisá-los.

# %% [markdown]
# Plotando gráfico de relação entre tempo e g-0

# %%
plt.figure(figsize = (10, 8)) #Aumentando tamanho da figura
sns.boxplot(x='tempo',y = 'g-0', data = dados) #Montando o gráfico boxplot

# %% [markdown]
# Plotando gráfico de relação entre dose e g-0

# %%
plt.figure(figsize = (10, 8)) #Aumentando tamanho da figura
sns.boxplot(x='dose',y = 'g-0', data = dados) #Montando o gráfico boxplot

# %% [markdown]
# Selecionando apenas um composto

# %%
plt.figure(figsize = (10, 8)) #Aumentando o tamanho da figura
sns.boxplot(y = 'dose', x = 'g-0' , data = dados.query('droga == "cacb2b860"')) #Plotando o boxplot

# %% [markdown]
# ================================================================================
#
# ##AULA 3 - CORRELAÇÕES, CAUSALIDADE E RELAÇÕES ENTRE GENES.

# %%
dados.head() #Mostrando as 5 primeiras linhas
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo']) #Relacionando tempo e dose
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento']) #Relacionando tempo, dose e tratamento
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'index') #Relacionando tempo, dose e tratamento e dando proporção
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 01: Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns') #Normalizando pela coluna
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 02: Criar tabelas de frequência com pandas.groupby().

# %%
com_droga = dados[dados['tratamento']=='com_droga'].groupby(['dose','tempo']).count()['tratamento']  #Agrupando por dose e tempo
com_droga #Mostrando a coluna
# Out:
# dose  tempo
# D1    24       3585
#       48       4011
#       72       3600
# D2    24       3581
#       48       3591
#       72       3580
# Name: tratamento, dtype: int64

# %%
com_controle = dados[dados['tratamento']=='com_controle'].groupby(['dose','tempo']).count()['tratamento'] #Agrupando por dose e tempo
com_controle # Mostrando a coluna
# Out:
# dose  tempo
# D1    24       301
#       48       343
#       72       307
# D2    24       305
#       48       305
#       72       305
# Name: tratamento, dtype: int64

# %%
tratamentos = pd.concat([com_controle, com_droga],axis = 1) #Agrupando em uma única tabela
tratamentos.columns = ['com_controle', 'com_droga'] #Deixando mais visualizavel
tratamentos #Mostrando a tabela
# Out:
#             com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
tratamentos.div(tratamentos.sum(axis = 1),axis = 0) #Colocando em porcentagem
# Out:
#             com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc = 'mean') #Crosstab com o g-0
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 03: Descobrir outros agregadores.

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.aggregate.html?highlight=aggfunc

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 04: Descobrir a ferramenta melt.

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.melt.html

# %%
pd.melt(dados,id_vars = ['tempo'],value_vars = ['g-0']) #Utilizando melt para conferir o tempo
# Out:
#        tempo variable   value
# 0         24      g-0  1.0620
# 1         72      g-0  0.0743
# 2         48      g-0  0.6280
# 3         48      g-0 -0.5138
# 4         72      g-0 -0.3254
# ...      ...      ...     ...
# 23809     24      g-0  0.1394
# 23810     24      g-0 -1.3260
# 23811     48      g-0  0.3942
# 23812     24      g-0  0.6660
# 23813     72      g-0 -0.8598
#
# [23814 rows x 3 columns]

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
dados[['g-0', 'g-3']] #Mostrando os dados de g-0 e g-3
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x = 'g-0', y = 'g-3', data = dados) #Plotando o gráfico scatterplot com x = g-0 e y = g-3

# %%
sns.scatterplot(x = 'g-0', y = 'g-8', data = dados) #Plotando o gráfico scatterplot com x = g-0 e y = g-8

# %%
sns.lmplot(data = dados, x = 'g-0', y = 'g-8', line_kws = {'color': 'red'}) #Plotando o gráfico lmplot com x = g-0 e y = g-3

# %%
sns.lmplot(data = dados, x = 'g-0', y = 'g-8', line_kws = {'color': 'red'}, col = 'tratamento') #Plotando o gráfico lmplot com x = g-0 e y = g-3 referente ao tratamento

# %%
sns.lmplot(data = dados, x = 'g-0', y = 'g-8', line_kws = {'color': 'red'}, col = 'tratamento', row = 'tempo') #Plotando o gráfico lmplot com x = g-0 e y = g-3 referente ao tempo

# %%
dados.loc[:, 'g-0':'g-771'].corr() #Encontrando a correlação
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %% [markdown]
# Percebemos, tanto pelo gráfico quanto pela tabela acima que o g-0 e o g-8 possuem uma correlação negativa, isto é, são inversamente proporcionais, ou seja, quando um aumenta, o outro decresce.

# %%
import numpy as np #Importano numby para criar matriz de correlação

corr = dados.loc[:, 'g-0':'g-50'].corr() #Armazenando em uma variável a correlação entre g-0 e g-50

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:, 'c-0':'c-50'].corr() #Armazenando em uma variável a correlação entre c-0 e c-50

mask = np.triu(np.ones_like(corr_celular, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# O c se refere a quantidade de cada tipo de celula que sobreviveu ao tratamento!!

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 05: Calcular a analisar a correlação entre g e c.

# %%
corr = dados.loc[:,'g-0':'c-99'].corr() #Armazenando em uma variável a correlação de g-0 até c-99

# %%
corr_celular_genes = corr.loc['g-0':'g-50','c-0':'c-50'] #Fazendo a correlação de g-0 até g-50 e de c-0 até c-50

# %%
f, ax = plt.subplots(figsize=(11, 9)) #Aumentando o tamanho da figura

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_celular_genes, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 06: Analisar o código que plota a matriz de correlação.

# %% [markdown]
# Gera-se uma matriz no tamanho do data frame de correlação, aplica-se uma máscara no triângulo superior, cria uma paleta de cores variando desde azul para correlações negativas até vermelho para correlações positivas. Por fim, é necessário desenhar um mapa de calor.

# %% [markdown]
# ================================================================================
#
# ##AULA 4 - MERGE DE DADOS E ANÁLISE DE RESULTADOS

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true') #Lendo os resultados
dados_resultados.head() #Mostrando as 5 primeiras linhas da tabela
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique() #Mostrando os valores únicos da acat_inhibitor
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique() #Mostrando os valores únicos da acetylcholine_receptor_agonist
# Out:
# array([0, 1])

# %%
contagem_mecanismos = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False) #Fazendo a contagem de quantos mecanismos cada composto ativou
contagem_mecanismos #Mostrando a contagem de mecanismos
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_mecanismos = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False) #Tirando os valores de ID e ordenando por ordem decrescente
contagem_mecanismos #Mostrando a contagem de mecanismos
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 01: Montar um TOP 10 das ações da contagem_mecanismo.

# %%
contagem_mecanismos.filter(like='inhibitor').head(10) #Fazendo top 10 dos inibidores
# Out:
# nfkb_inhibitor              832
# proteasome_inhibitor        726
# cyclooxygenase_inhibitor    435
# dna_inhibitor               402
# cdk_inhibitor               340
# egfr_inhibitor              336
# tubulin_inhibitor           316
# pdgfr_inhibitor             297
# hmgcr_inhibitor             283
# flt3_inhibitor              279
# dtype: int64

# %%
contagem_mecanismos.filter(like='antagonist').head(10) #Fazendo top 10 dos antagonistas
# Out:
# dopamine_receptor_antagonist         424
# serotonin_receptor_antagonist        404
# glutamate_receptor_antagonist        367
# adrenergic_receptor_antagonist       360
# acetylcholine_receptor_antagonist    301
# histamine_receptor_antagonist        241
# gaba_receptor_antagonist             165
# cc_chemokine_receptor_antagonist     102
# potassium_channel_antagonist          98
# adenosine_receptor_antagonist         96
# dtype: int64

# %%
contagem_mecanismos.filter(like='_agonist').head(10) #Fazendo top 10 dos agonistas
# Out:
# adrenergic_receptor_agonist        270
# glucocorticoid_receptor_agonist    266
# serotonin_receptor_agonist         236
# acetylcholine_receptor_agonist     190
# estrogen_receptor_agonist          158
# dopamine_receptor_agonist          121
# progesterone_receptor_agonist      119
# ppar_receptor_agonist              115
# gaba_receptor_agonist              106
# glutamate_receptor_agonist          74
# dtype: int64

# %%
contagem_mecanismos[0:10] #Fazendo top 10 geral
# Out:
# nfkb_inhibitor                    832
# proteasome_inhibitor              726
# cyclooxygenase_inhibitor          435
# dopamine_receptor_antagonist      424
# serotonin_receptor_antagonist     404
# dna_inhibitor                     402
# glutamate_receptor_antagonist     367
# adrenergic_receptor_antagonist    360
# cdk_inhibitor                     340
# egfr_inhibitor                    336
# dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
dados_resultados.drop('id', axis = 1).sum(axis = 1).sort_values(ascending = False) #Fazendo a contagem de mecanismos ativados
# Out:
# 21197    7
# 4849     7
# 19186    7
# 14316    7
# 20584    7
#         ..
# 6862     0
# 6861     0
# 11997    0
# 6859     0
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['numero_contagem_mecanismos'] = dados_resultados.drop('id', axis = 1).sum(axis = 1) #Armazenando em uma variável o número

# %%
dados_resultados['ativo_contagem_mecanismos'] = (dados_resultados['numero_contagem_mecanismos'] != 0) #Conferir se ativou ou não algum mecanismo
dados_resultados #Mostrando dados de resultado
# Out:
#                  id  ...  ativo_contagem_mecanismos
# 0      id_000644bb2  ...                       True
# 1      id_000779bfc  ...                      False
# 2      id_000a6266a  ...                       True
# 3      id_0015fd391  ...                      False
# 4      id_001626bd3  ...                       True
# ...             ...  ...                        ...
# 23809  id_fffb1ceed  ...                       True
# 23810  id_fffb70c0c  ...                       True
# 23811  id_fffc1c3f4  ...                      False
# 23812  id_fffcb9e7c  ...                       True
# 23813  id_ffffdd77b  ...                      False
#
# [23814 rows x 209 columns]

# %%
dados_merge = pd.merge(dados, dados_resultados[['id', 'numero_contagem_mecanismos', 'ativo_contagem_mecanismos']], on = 'id') #Fazendo um merge dos resultados e dos dados
dados_merge.head() #Mostrando o merge
# Out:
#              id  ... ativo_contagem_mecanismos
# 0  id_000644bb2  ...                      True
# 1  id_000779bfc  ...                     False
# 2  id_000a6266a  ...                      True
# 3  id_0015fd391  ...                     False
# 4  id_001626bd3  ...                      True
#
# [5 rows x 879 columns]

# %%
dados_merge.query('tratamento == "com_controle"')['ativo_contagem_mecanismos'].value_counts() #Conferinfo o número de com_controle
# Out:
# False    1866
# Name: ativo_contagem_mecanismos, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 02: Criar a coluna eh_controle para quando o tratamento for com controle.

# %%
dados_resultados['eh_controle'] = (dados['tratamento'] == 'com_controle') #Criando a coluna
dados_resultados.head() #Mostrando as 5 linhas da tabela resultados
# Out:
#              id  ...  eh_controle
# 0  id_000644bb2  ...        False
# 1  id_000779bfc  ...        False
# 2  id_000a6266a  ...        False
# 3  id_0015fd391  ...        False
# 4  id_001626bd3  ...        False
#
# [5 rows x 210 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','numero_contagem_mecanismos', 'ativo_contagem_mecanismos','eh_controle']], on='id') #Fazendo o merge de mais uma coluna
dados_combinados.head() #Mostrando a nova tabela
# Out:
#              id tratamento  ...  ativo_contagem_mecanismos eh_controle
# 0  id_000644bb2  com_droga  ...                       True       False
# 1  id_000779bfc  com_droga  ...                      False       False
# 2  id_000a6266a  com_droga  ...                       True       False
# 3  id_0015fd391  com_droga  ...                      False       False
# 4  id_001626bd3  com_droga  ...                       True       False
#
# [5 rows x 880 columns]

# %% [markdown]
# **Criei uma nova tabela para não impactar nas tabelas seguintes de dados_merge**

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 03: Criar três colunas para identificar o tempo em 24h, 48h e 72h.

# %%
dados_resultados['24'] = (dados['tempo'] == 24) #Criando coluna para tempo = 24h
dados_resultados['48'] = (dados['tempo'] == 48) #Criando coluna para tempo = 48h
dados_resultados['72'] = (dados['tempo'] == 72) #Criando coluna para tempo = 72h
dados_resultados.head() #Mostrando as 5 linhas da tabela
# Out:
#              id  5-alpha_reductase_inhibitor  ...     48     72
# 0  id_000644bb2                            0  ...  False  False
# 1  id_000779bfc                            0  ...  False   True
# 2  id_000a6266a                            0  ...   True  False
# 3  id_0015fd391                            0  ...   True  False
# 4  id_001626bd3                            0  ...  False   True
#
# [5 rows x 213 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','numero_contagem_mecanismos', 'ativo_contagem_mecanismos','eh_controle','24','48','72']], on='id') #Fazendo o merge e armazenando em uma nova variável
dados_combinados.head() #Mostrando as 5 linhas da tabela
# Out:
#              id tratamento  tempo dose  ... eh_controle     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %% [markdown]
# **Criei uma nova tabela para não impactar nas tabelas seguintes de dados_merge**

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 04: Estudar sobre combinações de DF.

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
dados_merge.query('tratamento == "com_droga"')['ativo_contagem_mecanismos'].value_counts() #Vendo o número de drogas que ativaram algum mecanismo
# Out:
# True     14447
# False     7501
# Name: ativo_contagem_mecanismos, dtype: int64

# %%
compostos_principais = dados_merge['droga']. value_counts().index[:6] #Armazenando os 5 compostos principais
plt.figure(figsize=(12, 8)) #Aumentando a figura
sns.boxplot(data = dados_merge.query('droga in @compostos_principais'), y ='g-0', x = 'droga', hue='ativo_contagem_mecanismos') #Criando gráfico boxplot

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose (escolher alguma droga e comparar com controle).

# %%
composto_principal = dados_merge['droga'].value_counts().index[:1] #Armazenando a droga mais utilizada

fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize = (20, 10)) #Definindo o tamanho da figura

sns.boxplot(data = dados_merge.query('droga in @composto_principal & tempo == 24'), y= 'g-0', x='droga',
            hue='ativo_contagem_mecanismos', order=composto_principal, ax=ax1) #Plotando gráfico 1 - tempo = 24h

sns.boxplot(data = dados_merge.query('droga in @composto_principal & tempo == 48'), y= 'g-0', x='droga',
            hue='ativo_contagem_mecanismos', order=composto_principal, ax=ax2) #Plotando gráfico 2 - tempo = 48h

sns.boxplot(data = dados_merge.query('droga in @composto_principal & tempo == 48'), y= 'g-0', x='droga',
            hue='ativo_contagem_mecanismos', order=composto_principal, ax=ax3) #Plotando gráfico 3 - tempo = 72h

plt.show() #Mostrando o gráfico

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(20, 10)) #Definindo o tamanho da figura

sns.boxplot(data = dados_merge.query('droga in @composto_principal & dose == "D1"'), y= 'g-0', x='droga',
            hue='ativo_contagem_mecanismos', order=composto_principal, ax=ax1) #Plotando gráfico 1 - Dose = D1

sns.boxplot(data = dados_merge.query('droga in @composto_principal & dose == "D2"'), y= 'g-0', x='droga',
            hue='ativo_contagem_mecanismos', order=composto_principal, ax=ax2) #Plotando gráfico 2 - Dose = D2

plt.show() #Mostrando gráfico

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 06: Descobrir se a configuração do experimento alterou a ativação de algum mecanismo de ação.

# %% [markdown]
# É possível perceber que o número de tempo quen o paciente foi exposto ao tratamento não alterou na ativação de algum mecanismo de ação.

# %% [markdown]
# ================================================================================
#
# ##AULA 5 - MACHINE LEARNING, SCI-KIT LEARNING E DESAFIOS ENVOLVIDOS.

# %%
dados_merge.head() #Mostrando as 5 linhas da tabela
# Out:
#              id  ... ativo_contagem_mecanismos
# 0  id_000644bb2  ...                      True
# 1  id_000779bfc  ...                     False
# 2  id_000a6266a  ...                      True
# 3  id_0015fd391  ...                     False
# 4  id_001626bd3  ...                      True
#
# [5 rows x 879 columns]

# %%
dados_resultados.head() #Mostrando as 5 linhas da tabela
# Out:
#              id  ...  ativo_contagem_mecanismos
# 0  id_000644bb2  ...                       True
# 1  id_000779bfc  ...                      False
# 2  id_000a6266a  ...                       True
# 3  id_0015fd391  ...                      False
# 4  id_001626bd3  ...                       True
#
# [5 rows x 209 columns]

# %%
from sklearn.linear_model import LogisticRegression #Importando regressão logística
from sklearn.model_selection import train_test_split #Selecionando modelo de teste

x = dados_merge.select_dtypes('float64')
y = dados_merge['ativo_contagem_mecanismos']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376) #Passando os parâmetros de treino e de teste

modelo_rlogistica = LogisticRegression(max_iter = 1000) #Fazendo a regressão logística
modelo_rlogistica.fit(x_treino, y_treino) #Passando o treino
modelo_rlogistica.score(x_teste, y_teste) #Passando o teste
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier #Importando a classificação Dummy
from sklearn.metrics import accuracy_score #Selecionando o modelo de teste

modelo_dummy = DummyClassifier ('most_frequent')
modelo_dummy.fit(x_treino, y_treino) #Treinando o modelo
previsao_dummy = modelo_dummy.predict(x_teste) #Previsão do modelo
accuracy_score(y_teste, previsao_dummy) #Acurácia do modelo
# Out:
# 0.6067604450976275

# %%
dados_merge['ativo_contagem_mecanismos'].value_counts(normalize = True) #Fazendo a contagem de True e False para a ativação dos mecanismos
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_contagem_mecanismos, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier #Importando Decision Tree

x = dados_merge.select_dtypes('float64')
y = dados_merge['ativo_contagem_mecanismos']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376) #Passando os parâmetros de treino e de teste

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino) #Treinando o modelo
modelo_arvore.score(x_teste, y_teste) #Fazendo os resultados do modelo
# Out:
# 0.6105395758975436

# %%
from sklearn.tree import DecisionTreeClassifier #Importando Decision Tree

x = dados_merge.select_dtypes('float64')
y = dados_merge['ativo_contagem_mecanismos']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

teste = [] #Armazenando os testes
treino = [] #Armazenando os treinos

for i in range (1, 15): #Fazendo um laço
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino, y_treino)
  teste.append(modelo_arvore.score(x_teste, y_teste)) #Adicionando os testes
  treino.append(modelo_arvore.score(x_treino, y_treino)) #Adicionando os treinos

# %%
teste #Mostrando o teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.6206172580306529,
#  0.6185177409195884,
#  0.6214570648750787,
#  0.6210371614528658,
#  0.6155784169640982,
#  0.6153684652529918,
#  0.6124291412975016,
#  0.5983623766533698,
#  0.6017216040310729,
#  0.5985723283644762]

# %%
treino #Mostrando o treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.6895176106241142,
#  0.7067870452994593,
#  0.7294630203138943,
#  0.7530838276205973,
#  0.7769670883418194,
#  0.7991181565272164]

# %%
sns.lineplot(x = range(1, 15), y = teste, label = 'teste') #Plotando gráfico gráfico de linha
sns.lineplot(x = range(1, 15), y = treino, label = 'treino') #Plotando gráfico gráfico de linha

# %%
pd.get_dummies(dados_merge['tratamento']) #Selecionando as opções da coluna tratamento
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_merge, columns = ['tratamento', 'dose', 'tempo']) #Fazendo as previsões relacionadas a tratamento, dose e tempo
# Out:
#                  id      droga     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
dados_merge.drop(['id', 'numero_contagem_mecanismos', 'ativo_contagem_mecanismos', 'droga'], axis=1) #Deixando de lado id, numero de mecanismos e ativações
# Out:
#          tratamento  tempo dose     g-0  ...    c-96    c-97    c-98    c-99
# 0         com_droga     24   D1  1.0620  ... -0.3981  0.2139  0.3801  0.4176
# 1         com_droga     72   D1  0.0743  ...  0.1522  0.1241  0.6077  0.7371
# 2         com_droga     48   D1  0.6280  ... -0.6417 -0.2187 -1.4080  0.6931
# 3         com_droga     48   D1 -0.5138  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4         com_droga     72   D2 -0.3254  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...    ...  ...     ...  ...     ...     ...     ...     ...
# 23809     com_droga     24   D2  0.1394  ...  0.0631  0.9171  0.5258  0.4680
# 23810     com_droga     24   D2 -1.3260  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  com_controle     48   D2  0.3942  ...  0.2256  0.7592  0.6656  0.3808
# 23812     com_droga     24   D1  0.6660  ...  0.1732  0.7015 -0.6290  0.0740
# 23813     com_droga     72   D1 -0.8598  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 875 columns]

# %%
from sklearn.ensemble import RandomForestClassifier #Importando Random Forest

x = dados_merge.drop(['id', 'numero_contagem_mecanismos', 'ativo_contagem_mecanismos', 'droga'], axis=1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose', 'tempo'])
y = dados_merge['ativo_contagem_mecanismos']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376) #Passando os parâmetros de treino e teste

modelo_randomForest = RandomForestClassifier()
modelo_randomForest.fit(x_treino, y_treino) #Treinando o modelo
modelo_randomForest.score(x_teste, y_teste) #Testando o modelo
# Out:
# 0.680033592273777

# %% [markdown]
# -------------------------------------------------------------------------------
#
# ###Desafio 01: Testar outros modelos

# %% [markdown]
# **Testando modelo de Regressão Logística com Newton-cg**

# %%
modelo_rlogistica = LogisticRegression(solver='newton-cg') ##Percebemos um valor bem mais satisfatório
modelo_rlogistica.fit(x_treino, y_treino) #Treinando o modelo
modelo_rlogistica.score(x_teste, y_teste) #Testando o modelo
# Out:
# 0.6640772622296872

# %% [markdown]
# **Testando modelo KNeighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier #Importando KNeighbors

n_neighbors = 3 #Definindo o número de vizinhos

clf = KNeighborsClassifier(n_neighbors)
clf.fit(x_treino, y_treino) #Treinando o modelo
clf.score(x_teste, y_teste) #Testando o modelo
# Out:
# 0.6155784169640982

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 02: Estudar a documentação do Sklearn

# %% [markdown]
# https://scikit-learn.org/stable/index.html

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 03: Pesquisar o fluxograma "escolhendo o melhor modelo"

# %% [markdown]
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 04: Testar com outras perguntas

# %% [markdown]
# **Testando com a coluna tempo**

# %%
x = dados_combinados.loc[:,'g-0':'c-99']

y = dados_merge['tempo'].map({24:0,48:1,72:2}) #Armazenando em y os valoes da coluna tempo
y #Mostrando a variável
# Out:
# 0        0
# 1        2
# 2        1
# 3        1
# 4        2
#         ..
# 23809    0
# 23810    0
# 23811    1
# 23812    0
# 23813    2
# Name: tempo, Length: 23814, dtype: int64
# 0        0
# 1        2
# 2        1
# 3        1
# 4        2
#         ..
# 23809    0
# 23810    0
# 23811    1
# 23812    0
# 23813    2
# Name: tempo, Length: 23814, dtype: int64

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376) #Passando os parâmetros de teste e treino

modelo_rlogistica2 = LogisticRegression(solver='newton-cg')
modelo_rlogistica2.fit(x_treino, y_treino) #Treinando o modelo
modelo_rlogistica2.score(x_teste, y_teste) #Testando o modelo
# Out:
# 0.686122191895864

# %%
modelo_dummy = DummyClassifier('most_frequent') #Usando o modelo dummy como comparaçãp
modelo_dummy.fit(x_treino, y_treino) #Treinando o modelo
previsao_dummy = modelo_dummy.predict(x_teste) #Revendo o modelo
accuracy_score(y_teste, previsao_dummy) #Acurácia do modelo
# Out:
# 0.3464203233256351

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------
#
# ###Desafio 05: Escolher a droga mais utilizada e tente criar um modelo para identificar se é com droga ou com controle

# %%
compostos_utilizados = dados_merge.query('droga in ["8b87a7a83", "5628cb3ee"]') #Armazenando os dois compostos

x = compostos_utilizados.loc[:,'g-0':'g-10'] #Aolicando de g-0 até g-10
y = compostos_utilizados['droga'].map({'8b87a7a83': 0, '5628cb3ee': 1})

sns.countplot(y=y) #Plotando o gráfico

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y,random_state=376) #Passando os parâmetros de treino e de teste

modelo_rlogistica2 = LogisticRegression()
modelo_rlogistica2.fit(x_treino, y_treino) #Treinando o modelo de regressão logística
modelo_rlogistica2.score(x_teste, y_teste) #Testando o modelo de regressão logística
# Out:
# 0.9382716049382716

# %%
modelo_dummy = DummyClassifier('most_frequent') #Comparando com modelo dummy
modelo_dummy.fit(x_treino, y_treino) #Treinando o modelo
previsao_dummy = modelo_dummy.predict(x_teste) #Fazendo a previsão do modelo
accuracy_score(y_teste, previsao_dummy) #Conferindo a acurácia
# Out:
# 0.5061728395061729

# %% [markdown]
# --------------------------------------------------------------------------------
